# %%
import pandas as pd

# %%
df = pd.read_csv('housepricedata.csv')

# %%
df
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# 5       14115            5            5          796         1         1
# 6       10084            8            5         1686         2         0
# 7       10382            7            6         1107         2         1
# 8        6120            7            5          952         2         0
# 9        7420            5            6          991         1         0
# 10      11200            5            5         1040         1         0
# 11      11924            9            5         1175         3         0
# ...

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]])

# %%
X = dataset[:, 0:10]

# %%
Y = dataset[:, 10]

# %%
from sklearn import preprocessing

# %% [markdown]
# Use a function called the min-max scaler, which scales the dataset so that all the input features lie between 0 and 1 inclusive

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
# Out:
# /home/wanhuixu/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X_scale
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %% [markdown]
# split our dataset into a training set and a test set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %% [markdown]
# Summary: In processing the data, we’ve:
#
# Read in the CSV (comma separated values) file and convert them to arrays.
# Split our dataset into the input features and the label.
# Scale the data so that the input features have similar orders of magnitude.
# Split our dataset into the training set, the validation set and the test set.

# %% [markdown]
# # Building and Training our First Neural Network

# %% [markdown]
# ## First Step: Setting up the Architecture

# %% [markdown]
# Hidden Layer1: 32 neurons, ReLU activation;
# Hidden Layer2: 32 neurons, ReLU activation;
# Output Layer: 1 neuron, Sigmoid activation.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %% [markdown]
# ## Second Step: Filling in the best numbers

# %% [markdown]
# Before we start our training, we have to configure the model by: 1.Telling it which algorithm you want to use to do the optimization; 2.Telling it what loss function to use; 3.Telling it what other metrics you want to track apart from the loss function

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# 'sgd' refers to stochastic gradient descent

# %% [markdown]
# the loss function for outputs that take the values 1 or 0 is called binary cross entropy

# %% [markdown]
# track accuracy on top of the loss function

# %%
hist = model.fit(X_train, Y_train, batch_size=32, epochs=100, validation_data=(X_val, Y_val))
# Out:
# Train on 1022 samples, validate on 219 samples
# Epoch 1/100
# 1022/1022 [==============================] - 1s 504us/step - loss: 0.7154 - acc: 0.4902 - val_loss: 0.7021 - val_acc: 0.5023
# Epoch 2/100
# 1022/1022 [==============================] - 0s 71us/step - loss: 0.6989 - acc: 0.5245 - val_loss: 0.6938 - val_acc: 0.6027
# Epoch 3/100
# 1022/1022 [==============================] - 0s 76us/step - loss: 0.6897 - acc: 0.5528 - val_loss: 0.6881 - val_acc: 0.4932
# Epoch 4/100
# 1022/1022 [==============================] - 0s 78us/step - loss: 0.6829 - acc: 0.5029 - val_loss: 0.6832 - val_acc: 0.4658
# Epoch 5/100
# 1022/1022 [==============================] - 0s 68us/step - loss: 0.6773 - acc: 0.4980 - val_loss: 0.6782 - val_acc: 0.4658
# Epoch 6/100
# 1022/1022 [==============================] - 0s 103us/step - loss: 0.6721 - acc: 0.5117 - val_loss: 0.6733 - val_acc: 0.4658
# Epoch 7/100
# ...

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 219/219 [==============================] - 0s 76us/step
# 0.8447488619856638

# %% [markdown]
# ## Summary

# %% [markdown]
# Coding up our first neural network required only a few lines of code: 1.We specify the architecture with the Keras Sequential model; 2.We specify some of our settings(optimizer, loss function, metrics to track) with model.compile; 3.We train our model(find the best parameters for our architecture) with the training data with model.fit; 4.We evaluate our model on the test set with model.evaluate

# %% [markdown]
# # Visualizing Loss and Accuracy

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# # Adding Regularization to our Neural Network

# %%
model_2 = Sequential([
    Dense(1000, activation='relu', input_shape=(10,)),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model_2.compile(optimizer='adam',
               loss='binary_crossentropy',
               metrics=['accuracy'])

# %%
hist_2 = model_2.fit(X_train, Y_train, 
                     batch_size=32, epochs=100, 
                     validation_data=(X_val, Y_val))
# Out:
# Train on 1022 samples, validate on 219 samples
# Epoch 1/100
# 1022/1022 [==============================] - 3s 3ms/step - loss: 0.5267 - acc: 0.7603 - val_loss: 0.4276 - val_acc: 0.8447
# Epoch 2/100
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.3580 - acc: 0.8679 - val_loss: 0.2962 - val_acc: 0.8721
# Epoch 3/100
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.3031 - acc: 0.8845 - val_loss: 0.2812 - val_acc: 0.8721
# Epoch 4/100
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.2805 - acc: 0.8796 - val_loss: 0.2880 - val_acc: 0.8584
# Epoch 5/100
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.2596 - acc: 0.8904 - val_loss: 0.2436 - val_acc: 0.8813
# Epoch 6/100
# 1022/1022 [==============================] - 2s 2ms/step - loss: 0.2387 - acc: 0.9022 - val_loss: 0.2252 - val_acc: 0.9087
# Epoch 7/100
# ...

# %% [markdown]
# Adam is one of the most common optimizers we use,which adds some tweaks to stochastic gradient descent such that it reaches the lower loss function faster.

# %%
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %% [markdown]
# This is a clear sign of over-fitting. The training loss is decreasing, but the validation loss is way above the training loss and increasing.

# %%
plt.plot(hist_2.history['acc'])
plt.plot(hist_2.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# We'll incorporate L2 regularization and dropout here.

# %%
from keras.layers import Dropout
from keras import regularizers

# %%
model_3 = Sequential([
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])

# %% [markdown]
# the differences between Model3 and Model2 are: 1.To add L2 regularization, notice that we've added a bit of extra code in each of our dense layers; 2.To add Dropout, we added a new layer.

# %%
model_3.compile(optimizer='adam',
               loss='binary_crossentropy',
               metrics=['accuracy'])

# %%
hist_3 = model_3.fit(X_train, Y_train,
                    batch_size=32, epochs=100,
                    validation_data=(X_val, Y_val))
# Out:
# Train on 1022 samples, validate on 219 samples
# Epoch 1/100
# 1022/1022 [==============================] - 5s 5ms/step - loss: 14.7219 - acc: 0.6057 - val_loss: 4.0648 - val_acc: 0.7671
# Epoch 2/100
# 1022/1022 [==============================] - 3s 3ms/step - loss: 1.7249 - acc: 0.8356 - val_loss: 0.6463 - val_acc: 0.8813
# Epoch 3/100
# 1022/1022 [==============================] - 3s 3ms/step - loss: 0.5645 - acc: 0.8669 - val_loss: 0.4729 - val_acc: 0.8858
# Epoch 4/100
# 1022/1022 [==============================] - 3s 3ms/step - loss: 0.5140 - acc: 0.8748 - val_loss: 0.4716 - val_acc: 0.8950
# Epoch 5/100
# 1022/1022 [==============================] - 3s 3ms/step - loss: 0.4939 - acc: 0.8806 - val_loss: 0.4439 - val_acc: 0.8995
# Epoch 6/100
# 1022/1022 [==============================] - 3s 3ms/step - loss: 0.4886 - acc: 0.8767 - val_loss: 0.6491 - val_acc: 0.7352
# Epoch 7/100
# ...

# %%
plt.plot(hist_3.history['loss'])
plt.plot(hist_3.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(top=1.2, bottom=0)
plt.show()

# %%
plt.plot(hist_3.history['acc'])
plt.plot(hist_3.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# ## Summary

# %% [markdown]
# To deal with overfittig, we can code in the following strategies into our model each with about one line of code: 1. L2 Regularization; 2. Dropout.

# %% [markdown]
# ## Consolidated Summary

# %% [markdown]
# We've written Python code to: 1. Explore and Process the Data; 2. Build and Train our Neural Network; 3. Visualize Loss and Accuracy; 4. Add Regularization to our Neural Network
